# %% [markdown]
# # Test Yourself
# DO THIS AFTER YOU WENT THROUGH EACH LAB

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#TASK
#You are given an csv file containing water points in Mulanje in Malawi
# Read the data into a dataframe called water_points
#Print the head of that dataframe

# %%
# TASK 1) Show statistics on how many pumps are of each type for all districts
# TASK 2) Create a histogram for that

# %% [markdown]
# TASK 3) Create the folling chart
# ![image.png](attachment:image.png)

# %% [markdown]
# TASK 4 Create the following table
# ![image.png](attachment:image.png)

# %%
#YOU TRY IT NOW
# 1) Create a bar chart for pump types in 'Nkanda TA'
# 2) Create a bar chart that shows the number of Afridev pumps per TA

# %% [markdown]
# TASK 5 Create the following Table
# ![image.png](attachment:image.png)

# %% [markdown]
# TASK 6) Create a bar chart showing all types of pumps in Mulanje distict
# TASK 7) DO the same for Phalombe

# %% [markdown]
# TASK 8) How many pumps are functional ineach District and Village_SI
# TASK 9) Show how many pumps of each WATER_SOUR type are functional per district
